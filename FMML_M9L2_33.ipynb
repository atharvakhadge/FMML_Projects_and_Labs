# %% [markdown]
# <a href="https://colab.research.google.com/github/atharvakhadge/FMML_Projects_and_Labs/blob/main/FMML_M9L2_33.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Foundation of Modern Machine Learning
# ## Module 9: Neural Networks
# ## Lab 2: Using MLP for multiclass classification
# #### Module Coordinator: Shantanu Agrawal

# %% [markdown]
# Till now, we got to know what is MLP, how it can be used for classification. We have done the single class classification in the previous lab session.
#
# In this notebook we will try to use an MLP for multiclass classification on the iris dataset.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Data preparation

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load the iris dataset
iris = load_iris()
X = iris['data']
y = iris['target']
names = iris['target_names']
feature_names = iris['feature_names']

# Scale data to have mean 0 and variance 1
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data set into training and testing
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=2)

# %% [markdown]
# # Visualising dataset

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
for target, target_name in enumerate(names):
    X_plot = X[y == target]
    ax1.plot(X_plot[:, 0], X_plot[:, 1],
             linestyle='none',
             marker='o',
             label=target_name)
ax1.set_xlabel(feature_names[0])
ax1.set_ylabel(feature_names[1])
ax1.axis('equal')
ax1.legend();

for target, target_name in enumerate(names):
    X_plot = X[y == target]
    ax2.plot(X_plot[:, 2], X_plot[:, 3],
             linestyle='none',
             marker='o',
             label=target_name)
ax2.set_xlabel(feature_names[2])
ax2.set_ylabel(feature_names[3])
ax2.axis('equal')
ax2.legend();

# %% [markdown]
# # Observing the dataset
#
# Thus, we can observe the dataset and see that there are *3 classes, setosa, versicolor, and virginica*.
#
# There are *4 features, sepal width, sepal length, petal width, petal length*.

# %% [markdown]
# # MLP for multiclass classification

# %%
import torch
import torch.nn.functional as F
import torch.nn as nn
from torch.autograd import Variable
import tqdm

# %%
# Defining the model architecture
class Model(nn.Module):
    def __init__(self, input_dim):
        super(Model, self).__init__()
        self.layer1 = nn.Linear(input_dim, 50)
        self.layer2 = nn.Linear(50, 50)
        self.layer3 = nn.Linear(50, 3)

    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        x = F.softmax(self.layer3(x), dim=1)
        return x

# %%
# Instantiating the model, using Adam optimiser, and Cross Entropy Loss, which is quite commonlu used for classification tasks.
model     = Model(X_train.shape[1])
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
loss_fn   = nn.CrossEntropyLoss()

# %% [markdown]
# # Train the model

# %%
# Train for 100 epochs
EPOCHS  = 100
X_train = torch.from_numpy(X_train).float()
X_test= torch.from_numpy(X_test).float()
y_test = torch.from_numpy(y_test)
y_train = torch.from_numpy(y_train)


loss_list     = np.zeros((EPOCHS,))
accuracy_list = np.zeros((EPOCHS,))

for epoch in tqdm.trange(EPOCHS):
    y_pred = model(X_train)
    loss = loss_fn(y_pred, y_train)
    loss_list[epoch] = loss.item()

    # Zero gradients
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    with torch.no_grad():
        y_pred = model(X_test)
        correct = (torch.argmax(y_pred, dim=1) == y_test).type(torch.FloatTensor)
        accuracy_list[epoch] = correct.mean()
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 420.68it/s]

# %% [markdown]
# # Plot training progress

# %%
fig, (ax1, ax2) = plt.subplots(2, figsize=(12, 6), sharex=True)

ax1.plot(accuracy_list)
ax1.set_ylabel("validation accuracy")
ax2.plot(loss_list)
ax2.set_ylabel("validation loss")
ax2.set_xlabel("epochs");

# %% [markdown]
# # Experiment with the neural network architecture
#
#
# 1.   Try changing the number of hidden layers.
# 2.   Try changing the number of neurons in the hidden layer.
# 3.   Try using a different activation function.
#
#
#
#
# Can you observe any changes?

# %% [markdown]
# # **Question -1**
#
# - The number of hidden layers was changed, adding an additional hidden layer likely increased the model's capacity to capture intricate patterns within the data. This could lead to a more complex decision boundary, potentially resulting in better performance on the training data.
# - The accuracy has increased.

# %%
# QUESTION -1


class Model1(nn.Module):
    def __init__(self, input_dim):
        super(Model1, self).__init__()
        self.layer1 = nn.Linear(input_dim, 50)
        self.layer2 = nn.Linear(50, 50)
        self.layer3 = nn.Linear(50, 3)

    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        x = F.softmax(self.layer3(x), dim=1)
        return x

model1 = Model1(X_train.shape[1])
optimizer1 = torch.optim.Adam(model1.parameters(), lr=0.001)

# Training loop
loss_list1 = np.zeros((EPOCHS,))
accuracy_list1 = np.zeros((EPOCHS,))

for epoch in tqdm.trange(EPOCHS):
    y_pred = model1(X_train)
    loss = loss_fn(y_pred, y_train)
    loss_list1[epoch] = loss.item()

    optimizer1.zero_grad()
    loss.backward()
    optimizer1.step()

    with torch.no_grad():
        y_pred = model1(X_test)
        correct = (torch.argmax(y_pred, dim=1) == y_test).type(torch.FloatTensor)
        accuracy_list1[epoch] = correct.mean()

# Plotting training progress
fig, (ax1, ax2) = plt.subplots(2, figsize=(12, 6), sharex=True)
ax1.plot(accuracy_list1)
ax1.set_ylabel("validation accuracy")
ax2.plot(loss_list1)
ax2.set_ylabel("validation loss")
ax2.set_xlabel("epochs");
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 594.48it/s]

# %% [markdown]
# # **Question-2**
#
# - Increasing the number of neurons typically enhances the model's ability to capture complex relationships within the data, as each neuron can learn different features.
# - The accuracy is very low in the starting but gradually increased.

# %%
# QUESTION -2
class Model2(nn.Module):
    def __init__(self, input_dim, hidden_dim):

        super(Model2, self).__init__()
        self.layer1 = nn.Linear(input_dim, hidden_dim)
        self.layer2 = nn.Linear(hidden_dim, 3)

    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.softmax(self.layer2(x), dim=1)
        return x

hidden_dim = 100  # Change the number of neurons here
model2 = Model2(X_train.shape[1], hidden_dim)
optimizer2 = torch.optim.Adam(model2.parameters(), lr=0.001)

# Training loop
loss_list2 = np.zeros((EPOCHS,))
accuracy_list2 = np.zeros((EPOCHS,))

for epoch in tqdm.trange(EPOCHS):
    y_pred = model2(X_train)
    loss = loss_fn(y_pred, y_train)
    loss_list2[epoch] = loss.item()

    optimizer2.zero_grad()
    loss.backward()
    optimizer2.step()

    with torch.no_grad():
        y_pred = model2(X_test)
        correct = (torch.argmax(y_pred, dim=1) == y_test).type(torch.FloatTensor)
        accuracy_list2[epoch] = correct.mean()

# Plotting training progress
fig, (ax1, ax2) = plt.subplots(2, figsize=(12, 6), sharex=True)
ax1.plot(accuracy_list2)
ax1.set_ylabel("validation accuracy")
ax2.plot(loss_list2)
ax2.set_ylabel("validation loss")
ax2.set_xlabel("epochs");
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 776.63it/s]

# %% [markdown]
# # **Question-3**
#
# - Tanh activation function, being symmetric around zero, might help mitigate the vanishing gradient problem and enable the model to learn more complex representations compared to ReLU.
#
#
#  - The accuracy also gradually increases

# %%
 # QUESTION -3


class Model3(nn.Module):
    def __init__(self, input_dim):
        super(Model3, self).__init__()
        self.layer1 = nn.Linear(input_dim, 50)
        self.layer2 = nn.Linear(50, 50)
        self.layer3 = nn.Linear(50, 3)

    def forward(self, x):
        x = F.tanh(self.layer1(x))  # Change activation function here
        x = F.tanh(self.layer2(x))  # Change activation function here
        x = F.softmax(self.layer3(x), dim=1)
        return x

model3 = Model3(X_train.shape[1])
optimizer3 = torch.optim.Adam(model3.parameters(), lr=0.001)

# Training loop
loss_list3 = np.zeros((EPOCHS,))
accuracy_list3 = np.zeros((EPOCHS,))

for epoch in tqdm.trange(EPOCHS):
    y_pred = model3(X_train)
    loss = loss_fn(y_pred, y_train)
    loss_list3[epoch] = loss.item()

    optimizer3.zero_grad()
    loss.backward()
    optimizer3.step()

    with torch.no_grad():
        y_pred = model3(X_test)
        correct = (torch.argmax(y_pred, dim=1) == y_test).type(torch.FloatTensor)
        accuracy_list3[epoch] = correct.mean()

# Plotting training progress
fig, (ax1, ax2) = plt.subplots(2, figsize=(12, 6), sharex=True)
ax1.plot(accuracy_list3)
ax1.set_ylabel("validation accuracy")
ax2.plot(loss_list3)
ax2.set_ylabel("validation loss")
ax2.set_xlabel("epochs");
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 605.40it/s]
